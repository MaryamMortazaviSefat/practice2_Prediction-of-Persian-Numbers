# %% [markdown]
# <a href="https://colab.research.google.com/github/MaryamMortazaviSefat/practice2_Prediction-of-Persian-Numbers/blob/main/q1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#loaad .py module
# !wget https://raw.githubusercontent.com/MaryamMortazaviSefat/practice2_Prediction-of-Persian-Numbers/refs/heads/main/data_hoda.py
# Out:
# --2024-09-21 10:37:53--  https://raw.githubusercontent.com/MaryamMortazaviSefat/practice2_Prediction-of-Persian-Numbers/refs/heads/main/data_hoda.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1084 (1.1K) [text/plain]
# Saving to: ‘data_hoda.py’
#
# data_hoda.py        100%[===================>]   1.06K  --.-KB/s    in 0s
#
# 2024-09-21 10:37:53 (70.2 MB/s) - ‘data_hoda.py’ saved [1084/1084]

# %%
import matplotlib.pyplot as plt
import numpy as np

from data_hoda import knn_classifier,load_hoda

# %%
x_train, y_train, x_test, y_test = load_hoda()

# %%
y=[]
x=list(range(2,171))
for k in x:
  y.append(knn_classifier(k,x_train,y_train,x_test,y_test))

# %%
plt.plot(x,y)
plt.xlabel('k')
plt.ylabel('acc')
plt.title('optimal k')
plt.show()

# %% [markdown]
# I think "3" is the optimal k for knn-classification in hoda dataset
